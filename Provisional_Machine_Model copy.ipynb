# %%
# Provisional machine learning model looking the accuracy of predicting forest fires in Alberta, CA
# Segment 1 Deliverables

# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
# Read CSVs (using raw files from https://wildfire.alberta.ca/resources/historical-data/historical-wildfire-database.aspx until ERD is set up)
fire_df = pd.read_csv("fires_2006to2018.csv")
fire_df
# Out:
#       fire_number fire_name  fire_year  calendar_year  assessment_datetime  \
# 0          CWF001       NaN       2006           2006  2006-04-02 16:00:00
# 1          CWF002       NaN       2006           2006  2006-04-03 16:45:00
# 2          CWF003       NaN       2006           2006  2006-04-08 20:05:00
# 3          CWF004       NaN       2006           2006  2006-04-13 18:20:00
# 4          CWF005       NaN       2006           2006  2006-04-14 17:25:00
# ...           ...       ...        ...            ...                  ...
# 19839      WWF051       NaN       2018           2018  2018-07-29 17:39:00
# 19840      WWF052       NaN       2018           2018  2018-08-20 12:09:00
# 19841      WWF053       NaN       2018           2018  2018-10-22 14:45:00
# 19842      WWF054       NaN       2018           2018  2018-10-23 15:45:00
# 19843      WWF055       NaN       2018           2018  2018-10-26 16:45:00
#
#        assessment_hectares  current_size size_class  fire_location_latitude  \
# 0                     0.20          0.20          B               51.152933
# 1                     0.01          0.01          A               51.157633
# 2                     0.01          0.01          A               51.194400
# 3                     0.75          0.75          B               51.125617
# 4                     0.01          0.01          A               50.409833
# ...                    ...           ...        ...                     ...
# 19839                 0.01          0.01          A               54.626783
# 19840                 0.01          0.01          A               54.350250
# 19841                 0.01          0.01          A               54.022550
# 19842                 0.01          0.01          A               54.023100
# 19843                 0.01          0.01          A               54.129350
#
#        fire_location_longitude  ... fuel_type     other_fuel_type  \
# 0                  -115.034600  ...       O1b                 NaN
# 1                  -115.002133  ...       O1b                 NaN
# 2                  -114.516167  ...       NaN            Campfire
# 3                  -114.841683  ...       O1a                 NaN
# 4                  -114.478967  ...       O1a                 NaN
# ...                        ...  ...       ...                 ...
# 19839              -115.598067  ...        C2                 NaN
# 19840              -115.083683  ...       NaN                Duff
# 19841              -115.668667  ...        D1                 NaN
# 19842              -115.669533  ...       NaN  Abandoned Campfire
# 19843              -115.374983  ...        M1                 NaN
#
#                 bh_fs_date bh_hectares           uc_fs_date uc_hectares  \
# 0      2006-04-02 16:00:00        0.20  2006-04-02 16:00:00        0.20
# 1      2006-04-03 16:45:00        0.01  2006-04-03 16:45:00        0.01
# 2      2006-04-08 20:05:00        0.01  2006-04-08 20:05:00        0.01
# 3      2006-04-13 18:20:00        0.75  2006-04-13 18:20:00        0.75
# 4      2006-04-14 17:25:00        0.01  2006-04-14 17:25:00        0.01
# ...                    ...         ...                  ...         ...
# 19839  2018-07-29 18:40:00        0.01  2018-07-29 20:20:00        0.01
# 19840  2018-08-20 12:09:00        0.01  2018-08-20 14:05:00        0.01
# 19841  2018-10-22 14:45:00        0.01  2018-10-22 14:46:00        0.01
# 19842  2018-10-23 15:45:00        0.01  2018-10-23 15:45:00        0.01
# 19843  2018-10-26 16:45:00        0.01  2018-10-26 16:45:00        0.01
#
#                 to_fs_date to_hectares           ex_fs_date ex_hectares
# 0                      NaN         NaN  2006-04-03 18:00:00        0.20
# 1                      NaN         NaN  2006-04-03 16:50:00        0.01
# 2                      NaN         NaN  2006-04-09 20:30:00        0.01
# 3                      NaN         NaN  2006-04-13 20:00:00        0.75
# 4                      NaN         NaN  2006-04-14 17:40:00        0.01
# ...                    ...         ...                  ...         ...
# 19839                  NaN         NaN  2018-07-29 20:53:00        0.01
# 19840  2018-08-20 14:15:00        0.01  2018-08-21 14:09:00        0.01
# 19841  2018-10-22 15:30:00        0.01  2018-10-23 15:54:00        0.01
# 19842                  NaN         NaN  2018-10-23 16:00:00        0.01
# 19843  2018-10-26 16:45:00        0.01  2018-10-29 13:30:00        0.01
#
# [19844 rows x 39 columns]

# %%
# Clean data by removing columns containing less useful data 
# Note that dates require reformatting for final modelling (currently removed for simplicity)
clean_fire_df = fire_df.drop(columns=["fire_number", "assessment_hectares", "assessment_datetime", "fire_start_date", "bh_fs_date", "uc_fs_date", "fire_name", "fire_year", "to_fs_date", "to_hectares", "ex_fs_date", "ex_hectares", "industry_identifier_desc", "initial_action_by", "current_size", "size_class", "fire_origin", "permit_detail_desc", "det_agent_type", "det_agent", "fire_fighting_start_date", "fire_fighting_start_size", "responsible_group_desc", "reported_date", "start_for_fire_date", "discovered_date"])
clean_fire_df
# Out:
#        calendar_year  fire_location_latitude  fire_location_longitude  \
# 0               2006               51.152933              -115.034600
# 1               2006               51.157633              -115.002133
# 2               2006               51.194400              -114.516167
# 3               2006               51.125617              -114.841683
# 4               2006               50.409833              -114.478967
# ...              ...                     ...                      ...
# 19839           2018               54.626783              -115.598067
# 19840           2018               54.350250              -115.083683
# 19841           2018               54.022550              -115.668667
# 19842           2018               54.023100              -115.669533
# 19843           2018               54.129350              -115.374983
#
#       general_cause_desc       activity_class         true_cause fire_type  \
# 0               Resident         Unclassified        Unsafe Fire   Surface
# 1           Undetermined                  NaN                NaN   Surface
# 2             Recreation              Cooking     Abandoned Fire    Ground
# 3               Resident              Smoking  Burning Substance   Surface
# 4               Resident              Cooking        Unsafe Fire   Surface
# ...                  ...                  ...                ...       ...
# 19839          Lightning                  NaN                NaN   Surface
# 19840           Resident      Debris Disposal        Unsafe Fire    Ground
# 19841           Resident      Debris Disposal        Unsafe Fire   Surface
# 19842           Resident  Cooking and Warming        Unsafe Fire   Surface
# 19843           Resident      Debris Disposal        Unsafe Fire    Ground
#
#       fire_position_on_slope weather_conditions_over_fire fuel_type  \
# 0                       Flat                        Clear       O1b
# 1                       Flat                       Cloudy       O1b
# 2                     Bottom                       Cloudy       NaN
# 3                     Bottom                       Cloudy       O1a
# 4                       Flat                       Cloudy       O1a
# ...                      ...                          ...       ...
# 19839                   Flat                        Clear        C2
# 19840                   Flat                        Clear       NaN
# 19841              Upper 1/3                        Clear        D1
# 19842                   Flat                        Clear       NaN
# 19843                   Flat                       Cloudy        M1
#
#           other_fuel_type  bh_hectares  uc_hectares
# 0                     NaN         0.20         0.20
# 1                     NaN         0.01         0.01
# 2                Campfire         0.01         0.01
# 3                     NaN         0.75         0.75
# 4                     NaN         0.01         0.01
# ...                   ...          ...          ...
# 19839                 NaN         0.01         0.01
# 19840                Duff         0.01         0.01
# 19841                 NaN         0.01         0.01
# 19842  Abandoned Campfire         0.01         0.01
# 19843                 NaN         0.01         0.01
#
# [19844 rows x 13 columns]

# %%
# Review data types
clean_fire_df.dtypes
# Out:
# calendar_year                     int64
# fire_location_latitude          float64
# fire_location_longitude         float64
# general_cause_desc               object
# activity_class                   object
# true_cause                       object
# fire_type                        object
# fire_position_on_slope           object
# weather_conditions_over_fire     object
# fuel_type                        object
# other_fuel_type                  object
# bh_hectares                     float64
# uc_hectares                     float64
# dtype: object

# %%
# Convert data types
clean_fire_df = clean_fire_df.astype({'calendar_year': 'float64'})

# %%
#Convert float to obj
#clean_fire_df["bh_hectares"] = clean_fire_df["bh_hectares"].astype(str)

# %%
# Check if changing data types worked
print(clean_fire_df.dtypes)
# Out:
# calendar_year                   float64
# fire_location_latitude          float64
# fire_location_longitude         float64
# general_cause_desc               object
# activity_class                   object
# true_cause                       object
# fire_type                        object
# fire_position_on_slope           object
# weather_conditions_over_fire     object
# fuel_type                        object
# other_fuel_type                  object
# bh_hectares                     float64
# uc_hectares                     float64
# dtype: object

# %%
# Review Null Values
clean_fire_df.isnull().sum()
# Out:
# calendar_year                       0
# fire_location_latitude              0
# fire_location_longitude             0
# general_cause_desc                  0
# activity_class                   7721
# true_cause                       8990
# fire_type                        2253
# fire_position_on_slope           2344
# weather_conditions_over_fire     2349
# fuel_type                        6040
# other_fuel_type                 16075
# bh_hectares                         0
# uc_hectares                         0
# dtype: int64

# %%
# Total null values in data
clean_fire_df.isnull().sum().sum()
# Out:
# 45772

# %%
# Replace Null Values with blank
final_df = clean_fire_df.fillna(value = "_")
final_df
# Out:
#        calendar_year  fire_location_latitude  fire_location_longitude  \
# 0             2006.0               51.152933              -115.034600
# 1             2006.0               51.157633              -115.002133
# 2             2006.0               51.194400              -114.516167
# 3             2006.0               51.125617              -114.841683
# 4             2006.0               50.409833              -114.478967
# ...              ...                     ...                      ...
# 19839         2018.0               54.626783              -115.598067
# 19840         2018.0               54.350250              -115.083683
# 19841         2018.0               54.022550              -115.668667
# 19842         2018.0               54.023100              -115.669533
# 19843         2018.0               54.129350              -115.374983
#
#       general_cause_desc       activity_class         true_cause fire_type  \
# 0               Resident         Unclassified        Unsafe Fire   Surface
# 1           Undetermined                    _                  _   Surface
# 2             Recreation              Cooking     Abandoned Fire    Ground
# 3               Resident              Smoking  Burning Substance   Surface
# 4               Resident              Cooking        Unsafe Fire   Surface
# ...                  ...                  ...                ...       ...
# 19839          Lightning                    _                  _   Surface
# 19840           Resident      Debris Disposal        Unsafe Fire    Ground
# 19841           Resident      Debris Disposal        Unsafe Fire   Surface
# 19842           Resident  Cooking and Warming        Unsafe Fire   Surface
# 19843           Resident      Debris Disposal        Unsafe Fire    Ground
#
#       fire_position_on_slope weather_conditions_over_fire fuel_type  \
# 0                       Flat                        Clear       O1b
# 1                       Flat                       Cloudy       O1b
# 2                     Bottom                       Cloudy         _
# 3                     Bottom                       Cloudy       O1a
# 4                       Flat                       Cloudy       O1a
# ...                      ...                          ...       ...
# 19839                   Flat                        Clear        C2
# 19840                   Flat                        Clear         _
# 19841              Upper 1/3                        Clear        D1
# 19842                   Flat                        Clear         _
# 19843                   Flat                       Cloudy        M1
#
#           other_fuel_type  bh_hectares  uc_hectares
# 0                       _         0.20         0.20
# 1                       _         0.01         0.01
# 2                Campfire         0.01         0.01
# 3                       _         0.75         0.75
# 4                       _         0.01         0.01
# ...                   ...          ...          ...
# 19839                   _         0.01         0.01
# 19840                Duff         0.01         0.01
# 19841                   _         0.01         0.01
# 19842  Abandoned Campfire         0.01         0.01
# 19843                   _         0.01         0.01
#
# [19844 rows x 13 columns]

# %%
# Join fuel type columns
final_df ['all_fuel_type'] = final_df['fuel_type'] + final_df['other_fuel_type']
final_df
# Out:
#        calendar_year  fire_location_latitude  fire_location_longitude  \
# 0             2006.0               51.152933              -115.034600
# 1             2006.0               51.157633              -115.002133
# 2             2006.0               51.194400              -114.516167
# 3             2006.0               51.125617              -114.841683
# 4             2006.0               50.409833              -114.478967
# ...              ...                     ...                      ...
# 19839         2018.0               54.626783              -115.598067
# 19840         2018.0               54.350250              -115.083683
# 19841         2018.0               54.022550              -115.668667
# 19842         2018.0               54.023100              -115.669533
# 19843         2018.0               54.129350              -115.374983
#
#       general_cause_desc       activity_class         true_cause fire_type  \
# 0               Resident         Unclassified        Unsafe Fire   Surface
# 1           Undetermined                    _                  _   Surface
# 2             Recreation              Cooking     Abandoned Fire    Ground
# 3               Resident              Smoking  Burning Substance   Surface
# 4               Resident              Cooking        Unsafe Fire   Surface
# ...                  ...                  ...                ...       ...
# 19839          Lightning                    _                  _   Surface
# 19840           Resident      Debris Disposal        Unsafe Fire    Ground
# 19841           Resident      Debris Disposal        Unsafe Fire   Surface
# 19842           Resident  Cooking and Warming        Unsafe Fire   Surface
# 19843           Resident      Debris Disposal        Unsafe Fire    Ground
#
#       fire_position_on_slope weather_conditions_over_fire fuel_type  \
# 0                       Flat                        Clear       O1b
# 1                       Flat                       Cloudy       O1b
# 2                     Bottom                       Cloudy         _
# 3                     Bottom                       Cloudy       O1a
# 4                       Flat                       Cloudy       O1a
# ...                      ...                          ...       ...
# 19839                   Flat                        Clear        C2
# 19840                   Flat                        Clear         _
# 19841              Upper 1/3                        Clear        D1
# 19842                   Flat                        Clear         _
# 19843                   Flat                       Cloudy        M1
#
#           other_fuel_type  bh_hectares  uc_hectares        all_fuel_type
# 0                       _         0.20         0.20                 O1b_
# 1                       _         0.01         0.01                 O1b_
# 2                Campfire         0.01         0.01            _Campfire
# 3                       _         0.75         0.75                 O1a_
# 4                       _         0.01         0.01                 O1a_
# ...                   ...          ...          ...                  ...
# 19839                   _         0.01         0.01                  C2_
# 19840                Duff         0.01         0.01                _Duff
# 19841                   _         0.01         0.01                  D1_
# 19842  Abandoned Campfire         0.01         0.01  _Abandoned Campfire
# 19843                   _         0.01         0.01                  M1_
#
# [19844 rows x 14 columns]

# %%
# Drop fuel type & other fuel type columns
final_df.drop(['fuel_type', 'other_fuel_type'], axis=1, inplace=True)

# %%
# Generate catergorical variable list 
df_cat = final_df.dtypes[final_df.dtypes == "object"].index.tolist()
df_cat
# Out:
# ['general_cause_desc',
#  'activity_class',
#  'true_cause',
#  'fire_type',
#  'fire_position_on_slope',
#  'weather_conditions_over_fire',
#  'all_fuel_type']

# %%
# Check number of unique values in each column
final_df[df_cat].nunique()
# Out:
# general_cause_desc                15
# activity_class                    35
# true_cause                        22
# fire_type                          6
# fire_position_on_slope             6
# weather_conditions_over_fire       6
# all_fuel_type                   1121
# dtype: int64

# %%
# Print out the fuel type value counts
fuel_counts = final_df.all_fuel_type.value_counts()
fuel_counts
# Out:
# C2_               5173
# O1a_              2874
# __                2278
# M2_               1774
# O1b_              1380
#                   ...
# _grass/brush         1
# _Furniture           1
# _School bus          1
# _Dry Log Decks       1
# _ground fire         1
# Name: all_fuel_type, Length: 1121, dtype: int64

# %%
# Determine which values to replace 
replace_fueltypes = list(fuel_counts[fuel_counts < 100].index)

# Replace in DataFrame
for fueltypes in replace_fueltypes:
    final_df.all_fuel_type = final_df.all_fuel_type.replace(fueltypes, "Other")

# Check to make sure binning was successful
final_df.all_fuel_type.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0             O1b_
# 1             O1b_
# 2        _Campfire
# 3             O1a_
# 4             O1a_
#            ...
# 19839          C2_
# 19840        Other
# 19841          D1_
# 19842        Other
# 19843          M1_
# Name: all_fuel_type, Length: 19844, dtype: object>

# %%
# Print out the fuel type value counts
fuel_counts = final_df.all_fuel_type.value_counts()
fuel_counts
# Out:
# C2_                    5173
# O1a_                   2874
# Other                  2749
# __                     2278
# M2_                    1774
# O1b_                   1380
# C3_                     538
# M1_                     477
# _Campfire               473
# C1_                     446
# D1_                     350
# S1_                     331
# S2_                     329
# _Abandoned campfire     306
# _Garbage                142
# C4_                     112
# _campfire               112
# Name: all_fuel_type, dtype: int64

# %%
# Check number of unique values in each column
final_df[df_cat].nunique()
# Out:
# general_cause_desc              15
# activity_class                  35
# true_cause                      22
# fire_type                        6
# fire_position_on_slope           6
# weather_conditions_over_fire     6
# all_fuel_type                   17
# dtype: int64

# %%
# Need to review other cat values and keep binning if over 10 values

# %%
# Create the OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit the encoder & produce encoded DataFrame
encode_df = pd.DataFrame(enc.fit_transform(final_df[df_cat]))

# Rename encoded columns
encode_df.columns = enc.get_feature_names([df_cat])
encode_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-608-56ce92e0d2d0> in <module>
#       6
#       7 # Rename encoded columns
# ----> 8 encode_df.columns = enc.get_feature_names([df_cat])
#       9 encode_df.head()
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py in get_feature_names(self, input_features)
#     623                 "input_features should have length equal to number of "
#     624                 "features ({}), got {}".format(len(self.categories_),
# --> 625                                                len(input_features)))
#     626
#     627         feature_names = []
#
# ValueError: input_features should have length equal to number of features (7), got 1

# %%
# Merge the two Dataframes together and drop all fuel types column
## final_df.merge(encode_df, left_index=True, right_index=True).drop('all_fuel_type',1)

# %%
# Decide on features and label: 
# Features are date of the fire, latitude, longitude, cause of fire, type of fire, weather conditions, fire position, fuel type 
# Output labels is the date & size of the fire being under controlled i.e. how big the fire became
# The model will aim to calculate these parameters input and provide the probability in predicting the size of potential forest fires

# Output labels 
y = final_df["bh_hectares"]

# Features data 
X = final_df.drop(columns=["bh_hectares"])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data 
X_trained_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-563-636695d82103> in <module>
#       3
#       4 # Fit the StandardScaler
# ----> 5 X_scaler = scaler.fit(X_train)
#       6
#       7 # Scale the data
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
# --> 768                                 force_all_finite='allow-nan', reset=first_call)
#     769         n_features = X.shape[1]
#     770
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Lightning'
