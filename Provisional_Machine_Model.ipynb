# %%
Provisional machine learning model looking the accuracy of predicting forest fires in Alberta, CA
Segment 1 Deliverables

# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import pandas as pd
import tensorflow as tf

# %%
# Read CSVs (using raw files from https://wildfire.alberta.ca/resources/historical-data/historical-wildfire-database.aspx until ERD is set up)
fire_df = pd.concat(map(pd.read_csv, ["fires_2006to2018.csv", "fires_1996to2005.csv"]))
fire_df
# Out:
#       fire_number fire_name  fire_year  calendar_year  assessment_datetime  \
# 0          CWF001       NaN       2006           2006  2006-04-02 16:00:00
# 1          CWF002       NaN       2006           2006  2006-04-03 16:45:00
# 2          CWF003       NaN       2006           2006  2006-04-08 20:05:00
# 3          CWF004       NaN       2006           2006  2006-04-13 18:20:00
# 4          CWF005       NaN       2006           2006  2006-04-14 17:25:00
# ...           ...       ...        ...            ...                  ...
# 11347      WWF051       NaN       2005           2005  2005-11-09 15:06:00
# 11348      WWF052       NaN       2005           2005  2005-11-22 13:00:00
# 11349      WWF053       NaN       2005           2005  2005-11-24 14:00:00
# 11350      WWF054       NaN       2005           2006  2006-02-13 11:00:00
# 11351      WWF055       NaN       2005           2006  2006-03-26 17:05:00
#
#        assessment_hectares  current_size size_class  fire_location_latitude  \
# 0                     0.20          0.20          B               51.152933
# 1                     0.01          0.01          A               51.157633
# 2                     0.01          0.01          A               51.194400
# 3                     0.75          0.75          B               51.125617
# 4                     0.01          0.01          A               50.409833
# ...                    ...           ...        ...                     ...
# 11347                 0.01          0.01          A               54.230383
# 11348                 0.10          0.60          B               54.626694
# 11349                 0.01          0.01          A               54.539409
# 11350                 0.50          0.50          B               54.757621
# 11351                 0.01          0.01          A               54.011969
#
#        fire_location_longitude  ... fuel_type other_fuel_type  \
# 0                  -115.034600  ...       O1b             NaN
# 1                  -115.002133  ...       O1b             NaN
# 2                  -114.516167  ...       NaN        Campfire
# 3                  -114.841683  ...       O1a             NaN
# 4                  -114.478967  ...       O1a             NaN
# ...                        ...  ...       ...             ...
# 11347              -115.749217  ...        M1             NaN
# 11348              -115.371483  ...        C3             NaN
# 11349              -115.119440  ...        C2             NaN
# 11350              -115.383929  ...        S1             NaN
# 11351              -115.453639  ...        S2             NaN
#
#                 bh_fs_date bh_hectares           uc_fs_date uc_hectares  \
# 0      2006-04-02 16:00:00        0.20  2006-04-02 16:00:00        0.20
# 1      2006-04-03 16:45:00        0.01  2006-04-03 16:45:00        0.01
# 2      2006-04-08 20:05:00        0.01  2006-04-08 20:05:00        0.01
# 3      2006-04-13 18:20:00        0.75  2006-04-13 18:20:00        0.75
# 4      2006-04-14 17:25:00        0.01  2006-04-14 17:25:00        0.01
# ...                    ...         ...                  ...         ...
# 11347  2005-11-09 15:06:00        0.01  2005-11-09 16:00:00        0.01
# 11348  2005-11-22 15:30:00        0.20  2005-11-22 18:00:00        0.60
# 11349  2005-11-24 14:01:00        0.01  2005-11-24 14:01:00        0.01
# 11350  2006-02-13 11:00:00        0.50  2006-02-15 12:45:00        0.50
# 11351  2006-03-26 17:06:00        0.01  2006-03-26 17:06:00        0.01
#
#                 to_fs_date to_hectares           ex_fs_date ex_hectares
# 0                      NaN         NaN  2006-04-03 18:00:00        0.20
# 1                      NaN         NaN  2006-04-03 16:50:00        0.01
# 2                      NaN         NaN  2006-04-09 20:30:00        0.01
# 3                      NaN         NaN  2006-04-13 20:00:00        0.75
# 4                      NaN         NaN  2006-04-14 17:40:00        0.01
# ...                    ...         ...                  ...         ...
# 11347                  NaN         NaN  2005-11-10 11:00:00        0.01
# 11348  2005-11-24 14:00:00        0.60  2005-12-21 10:51:00        0.60
# 11349                  NaN         NaN  2005-11-24 14:02:00        0.01
# 11350  2006-02-13 16:00:00        0.50  2006-02-15 13:00:00        0.50
# 11351  2006-03-26 17:10:00        0.01  2006-03-31 09:15:00        0.01
#
# [31196 rows x 39 columns]

# %%
# Clean data by removing columns containing less useful data 
clean_fire_df = fire_df.drop(columns=["fire_number", "assessment_hectares","calendar_year", "fire_name", "fire_year", "to_fs_date", "to_hectares", "ex_fs_date", "ex_hectares", "industry_identifier_desc", "initial_action_by", "current_size", "size_class", "fire_origin"])
clean_fire_df
# Out:
#        assessment_datetime  fire_location_latitude  fire_location_longitude  \
# 0      2006-04-02 16:00:00               51.152933              -115.034600
# 1      2006-04-03 16:45:00               51.157633              -115.002133
# 2      2006-04-08 20:05:00               51.194400              -114.516167
# 3      2006-04-13 18:20:00               51.125617              -114.841683
# 4      2006-04-14 17:25:00               50.409833              -114.478967
# ...                    ...                     ...                      ...
# 11347  2005-11-09 15:06:00               54.230383              -115.749217
# 11348  2005-11-22 13:00:00               54.626694              -115.371483
# 11349  2005-11-24 14:00:00               54.539409              -115.119440
# 11350  2006-02-13 11:00:00               54.757621              -115.383929
# 11351  2006-03-26 17:05:00               54.011969              -115.453639
#
#        general_cause_desc       responsible_group_desc activity_class  \
# 0                Resident                     Resident   Unclassified
# 1            Undetermined                          NaN            NaN
# 2              Recreation                       Hikers        Cooking
# 3                Resident                     Resident        Smoking
# 4                Resident                     Resident        Cooking
# ...                   ...                          ...            ...
# 11347          Recreation                      Hunters        Cooking
# 11348      Other Industry  Others (explain in remarks)          Brush
# 11349          Recreation                      Hunters        Cooking
# 11350     Forest Industry                  Contractors          Brush
# 11351  Oil & Gas Industry         Construction Workers          Piles
#
#               true_cause permit_detail_desc      fire_start_date  \
# 0            Unsafe Fire                NaN  2006-04-02 14:25:00
# 1                    NaN                NaN  2006-04-03 15:30:00
# 2         Abandoned Fire                NaN  2006-04-08 19:00:00
# 3      Burning Substance                NaN  2006-04-13 17:33:00
# 4            Unsafe Fire                NaN  2006-04-14 15:17:00
# ...                  ...                ...                  ...
# 11347     Abandoned Fire                NaN  2005-11-05 18:00:00
# 11348    Unattended Fire                NaN  2005-11-01 12:00:00
# 11349     Abandoned Fire                NaN  2005-11-05 12:00:00
# 11350    Unattended Fire                NaN  2006-01-30 12:00:00
# 11351     Permit Related                NaN  2006-03-26 12:00:00
#
#       det_agent_type  ... fire_fighting_start_size fire_type  \
# 0                UNP  ...                      NaN   Surface
# 1                UNP  ...                      NaN   Surface
# 2                UNP  ...                     0.01    Ground
# 3                UNP  ...                      NaN   Surface
# 4                UNP  ...                      NaN   Surface
# ...              ...  ...                      ...       ...
# 11347            UNP  ...                      NaN    Ground
# 11348            UNP  ...                     0.20   Surface
# 11349            UNP  ...                      NaN    Ground
# 11350            UNP  ...                      NaN   Surface
# 11351            UNP  ...                      NaN   Surface
#
#       fire_position_on_slope weather_conditions_over_fire fuel_type  \
# 0                       Flat                        Clear       O1b
# 1                       Flat                       Cloudy       O1b
# 2                     Bottom                       Cloudy       NaN
# 3                     Bottom                       Cloudy       O1a
# 4                       Flat                       Cloudy       O1a
# ...                      ...                          ...       ...
# 11347                   Flat                        Clear        M1
# 11348                   Flat                        Clear        C3
# 11349                   Flat                        Clear        C2
# 11350                   Flat                        Clear        S1
# 11351                   Flat                        Clear        S2
#
#        other_fuel_type           bh_fs_date bh_hectares           uc_fs_date  \
# 0                  NaN  2006-04-02 16:00:00        0.20  2006-04-02 16:00:00
# 1                  NaN  2006-04-03 16:45:00        0.01  2006-04-03 16:45:00
# 2             Campfire  2006-04-08 20:05:00        0.01  2006-04-08 20:05:00
# 3                  NaN  2006-04-13 18:20:00        0.75  2006-04-13 18:20:00
# 4                  NaN  2006-04-14 17:25:00        0.01  2006-04-14 17:25:00
# ...                ...                  ...         ...                  ...
# 11347              NaN  2005-11-09 15:06:00        0.01  2005-11-09 16:00:00
# 11348              NaN  2005-11-22 15:30:00        0.20  2005-11-22 18:00:00
# 11349              NaN  2005-11-24 14:01:00        0.01  2005-11-24 14:01:00
# 11350              NaN  2006-02-13 11:00:00        0.50  2006-02-15 12:45:00
# 11351              NaN  2006-03-26 17:06:00        0.01  2006-03-26 17:06:00
#
#       uc_hectares
# 0            0.20
# 1            0.01
# 2            0.01
# 3            0.75
# 4            0.01
# ...           ...
# 11347        0.01
# 11348        0.60
# 11349        0.01
# 11350        0.50
# 11351        0.01
#
# [31196 rows x 25 columns]

# %%
# Decide on features and label: 
# Features are date of the fire, latitude, longitude, cause of fire, who detected the fire, was there a permit for the fire, type of fire, weather conditions, fire position, fuel type 
# Output labels is the date & size of the fire being under controlled i.e. how big the fire became & how long it took to be under controlled
# The model will aim to calculate these parameters input and provide the probability in predicting the size and duration of potential forest fires

# Output labels 
y = clean_fire_df(columns=["bh_fs_date", "bh_hectares"])

# Features data 
X = clean_fire_df.drop(columns=["bh_fs_date", "bh_hectares"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-4e2136f0cf9d> in <module>
#       2
#       3 # Output labels = bh_hectares & bh_date (date & size of fire held)
# ----> 4 y = clean_fire_df(columns=["bh_fs_date", "bh_hectares"])
#       5
#       6 # Features data = date of fire, lat, long, cause of fire, who detected the fire, whether there was a permit for the fire, type of fire, weather conditions, fire position, fuel type
#
# TypeError: 'DataFrame' object is not callable
